# %%
import numpy as np
import h5py as h5
from matplotlib import pyplot as plt
from IPython.display import Image
import tensorflow as tf
import sys
import keras
from omnifold.net import weighted_binary_crossentropy

# Register OmniFold custom loss so Keras 3 can clone models
keras.saving.register_keras_serializable(package="omnifold")(weighted_binary_crossentropy)
# Out:
# <function omnifold.net.weighted_binary_crossentropy(y_true, y_pred)>

# %%
import os
import sys
sys.path.append("/scratch/mjosef/Unfolding/test/omnifold/omnifold")  # Add the omnifold package directory

# If omnifold is not installed as a package, ensure the path is correct above.
from omnifold import DataLoader, MLP, MultiFold, SetStyle, HistRoutine
# Out:
# Horovod not found, will continue with single only GPUs.

# %% [markdown]
# # OmniFold example using high-level features as inputs

# %%
def detector(x,std = 0.5):
    """ Create a fake detector response that smears the inputs given a gaussian distribution with mean 0 and std"""
    return x + np.random.normal(size=x.shape)*std

# %%
nevts = 1_000_000 #Number of training events we are going to use
ndim = 4 #Number of features we are going to create

# %%
gen_data = np.random.normal(size=(nevts,ndim),loc=ndim*[0.0],scale=ndim*[1.0])
reco_data = detector(gen_data)
gen_mc = np.random.normal(size=(nevts,ndim),loc=ndim*[1.0],scale=ndim*[1.0])
reco_mc = detector(gen_mc)

data = DataLoader(reco = reco_data,normalize=True)
mc = DataLoader(reco = reco_mc,gen = gen_mc,normalize=True)
# Out:
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...

# %% [markdown]
# ## Let's take a quick look at the data

# %%
SetStyle()
data_dict = {
    'Truth Distribution': gen_data[:,0],
    'Reconstructed Data': reco_data[:,0],
    'Generated MC': gen_mc[:,0],
    'Reconstructed MC': reco_mc[:,0],
}
HistRoutine(data_dict,'First Feature [a.u]', reference_name = 'Truth Distribution',plot_ratio=True, binning = np.linspace(-3,5,20),)
# Out:
# (<Figure size 900x900 with 2 Axes>,
#  <Axes: ylabel='Normalized number of events'>)

# %% [markdown]
# ## Let's now create the neural network models we are going to use to model the weight distributions

# %%
model1 = MLP(ndim)
model2 = MLP(ndim)
# Out:
# I0000 00:00:1764929366.918775 3430563 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 139432 MB memory:  -> device: 0, name: NVIDIA H200, pci bus id: 0000:03:00.0, compute capability: 9.0
# I0000 00:00:1764929366.921389 3430563 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 138038 MB memory:  -> device: 1, name: NVIDIA H200, pci bus id: 0000:23:00.0, compute capability: 9.0
# I0000 00:00:1764929366.927369 3430563 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 140836 MB memory:  -> device: 2, name: NVIDIA H200, pci bus id: 0000:43:00.0, compute capability: 9.0
# I0000 00:00:1764929366.929426 3430563 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 140836 MB memory:  -> device: 3, name: NVIDIA H200, pci bus id: 0000:63:00.0, compute capability: 9.0
# I0000 00:00:1764929366.931940 3430563 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 140834 MB memory:  -> device: 4, name: NVIDIA H200, pci bus id: 0000:83:00.0, compute capability: 9.0
# I0000 00:00:1764929366.934613 3430563 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 138032 MB memory:  -> device: 5, name: NVIDIA H200, pci bus id: 0000:a3:00.0, compute capability: 9.0
# I0000 00:00:1764929366.937664 3430563 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 140838 MB memory:  -> device: 6, name: NVIDIA H200, pci bus id: 0000:c3:00.0, compute capability: 9.0
# I0000 00:00:1764929366.940124 3430563 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 137027 MB memory:  -> device: 7, name: NVIDIA H200, pci bus id: 0000:e3:00.0, compute capability: 9.0

# %%
print(model1.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Let's now unfold!

# %%
omnifold = MultiFold(
    "Gaussian_test",
    model1,
    model2,
    data,
    mc,
    batch_size = 512,
    niter = 5,  #Number of Iterations                                                                                                                                                                                                  
    epochs=100,     
    weights_folder = 'weights',
    verbose = True,
    lr = 5e-5,
)
# Out:
# 3906 training steps at reco and 3906 steps at gen

# %%
omnifold.Unfold()
# Out:
# ITERATION: 1
# RUNNING STEP 1
# Creating cached data from step 1
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764929622.193176 3431071 service.cc:152] XLA service 0x7f399c0051c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1764929622.193211 3431071 service.cc:160]   StreamExecutor device (0): NVIDIA H200, Compute Capability 9.0
# I0000 00:00:1764929622.193215 3431071 service.cc:160]   StreamExecutor device (1): NVIDIA H200, Compute Capability 9.0
# I0000 00:00:1764929622.193219 3431071 service.cc:160]   StreamExecutor device (2): NVIDIA H200, Compute Capability 9.0
# I0000 00:00:1764929622.193221 3431071 service.cc:160]   StreamExecutor device (3): NVIDIA H200, Compute Capability 9.0
# I0000 00:00:1764929622.193224 3431071 service.cc:160]   StreamExecutor device (4): NVIDIA H200, Compute Capability 9.0
# I0000 00:00:1764929622.193226 3431071 service.cc:160]   StreamExecutor device (5): NVIDIA H200, Compute Capability 9.0
# I0000 00:00:1764929622.193228 3431071 service.cc:160]   StreamExecutor device (6): NVIDIA H200, Compute Capability 9.0
# I0000 00:00:1764929622.193230 3431071 service.cc:160]   StreamExecutor device (7): NVIDIA H200, Compute Capability 9.0
# 2025-12-05 11:13:42.249649: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1764929622.502186 3431071 cuda_dnn.cc:529] Loaded cuDNN version 90501
#    1/3124 ━━━━━━━━━━━━━━━━━━━━ 4:32:54 5s/step - loss: 0.6914
# I0000 00:00:1764929623.197281 3431071 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.4746 - val_loss: 0.4057 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4047 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4052 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4054 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4049 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4041 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4048 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4045 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4046 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4056 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4040 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4046 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 13/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4053 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 14/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4047 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 15/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4048 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 16/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4051 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 17/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4054 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 18/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4052 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 19/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4052 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Epoch 20/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4048 - val_loss: 0.4055 - learning_rate: 5.0000e-05
# Last val loss 0.40568408370018005
# INFO: Dumping training history ...
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step
# RUNNING STEP 2
# Creating cached data from step 2
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.5379 - val_loss: 0.4519 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4512 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4507 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4509 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4509 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4506 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4513 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.4512 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4511 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4509 - val_loss: 0.4517 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4511 - val_loss: 0.4517 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4507 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 13/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4511 - val_loss: 0.4517 - learning_rate: 5.0000e-05
# Epoch 14/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4510 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 15/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4510 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 16/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4511 - val_loss: 0.4517 - learning_rate: 5.0000e-05
# Epoch 17/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4503 - val_loss: 0.4517 - learning_rate: 5.0000e-05
# Epoch 18/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.4514 - val_loss: 0.4517 - learning_rate: 5.0000e-05
# Epoch 19/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4501 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Epoch 20/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.4504 - val_loss: 0.4518 - learning_rate: 5.0000e-05
# Last val loss 0.4519384801387787
# INFO: Dumping training history ...
# 1954/1954 ━━━━━━━━━━━━━━━━━━━━ 2s 841us/step
# ITERATION: 2
# RUNNING STEP 1
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.7261 - val_loss: 0.6736 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6748 - val_loss: 0.6728 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6752 - val_loss: 0.6725 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6748 - val_loss: 0.6723 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6723 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6727 - val_loss: 0.6723 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6752 - val_loss: 0.6723 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6721 - val_loss: 0.6727 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6716 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6746 - val_loss: 0.6724 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6729 - val_loss: 0.6723 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6764 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 13/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6755 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 14/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6765 - val_loss: 0.6723 - learning_rate: 5.0000e-05
# Epoch 15/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6744 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 16/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.6733 - val_loss: 0.6723 - learning_rate: 5.0000e-05
# Epoch 17/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6734 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 18/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6704 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 19/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.6745 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 20/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6740 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 21/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6735 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 22/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6736 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 23/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.6721 - val_loss: 0.6724 - learning_rate: 5.0000e-05
# Epoch 24/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6735 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 25/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6745 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 26/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6730 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 27/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6727 - val_loss: 0.6724 - learning_rate: 5.0000e-05
# Epoch 28/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6705 - val_loss: 0.6722 - learning_rate: 5.0000e-05
# Epoch 29/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6758 - val_loss: 0.6723 - learning_rate: 5.0000e-05
# Last val loss 0.673629105091095
# INFO: Dumping training history ...
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step
# RUNNING STEP 2
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.3738 - val_loss: 0.3736 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3738 - val_loss: 0.3735 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3735 - val_loss: 0.3735 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3733 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3729 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3731 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3731 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3737 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3724 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3733 - val_loss: 0.3736 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3735 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3735 - val_loss: 0.3735 - learning_rate: 5.0000e-05
# Epoch 13/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3731 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 14/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3735 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 15/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3738 - val_loss: 0.3735 - learning_rate: 5.0000e-05
# Epoch 16/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3734 - val_loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 17/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3729 - val_loss: 0.3735 - learning_rate: 5.0000e-05
# Last val loss 0.37356650829315186
# INFO: Dumping training history ...
# 1954/1954 ━━━━━━━━━━━━━━━━━━━━ 3s 844us/step
# ITERATION: 3
# RUNNING STEP 1
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.7009 - val_loss: 0.6979 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.7057 - val_loss: 0.6977 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.7035 - val_loss: 0.6979 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6986 - val_loss: 0.6979 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6968 - val_loss: 0.6983 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6993 - val_loss: 0.6983 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6991 - val_loss: 0.6983 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.7019 - val_loss: 0.6978 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6988 - val_loss: 0.6982 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.7039 - val_loss: 0.6978 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6991 - val_loss: 0.6980 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.7010 - val_loss: 0.6979 - learning_rate: 5.0000e-05
# Last val loss 0.6978744268417358
# INFO: Dumping training history ...
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step
# RUNNING STEP 2
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.3581 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3590 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3591 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3584 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3592 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3593 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3587 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3593 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3585 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3592 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3587 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3591 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Epoch 13/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3588 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Epoch 14/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3596 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 15/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3595 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 16/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3592 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 17/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.3589 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Epoch 18/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3588 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Epoch 19/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3591 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Epoch 20/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3590 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 21/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3587 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 22/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3591 - val_loss: 0.3590 - learning_rate: 5.0000e-05
# Last val loss 0.35904380679130554
# INFO: Dumping training history ...
# 1954/1954 ━━━━━━━━━━━━━━━━━━━━ 2s 850us/step
# ITERATION: 4
# RUNNING STEP 1
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.6911 - val_loss: 0.6880 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6883 - val_loss: 0.6880 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6924 - val_loss: 0.6883 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6939 - val_loss: 0.6881 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6921 - val_loss: 0.6881 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6951 - val_loss: 0.6881 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6877 - val_loss: 0.6881 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6895 - val_loss: 0.6886 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6907 - val_loss: 0.6881 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6942 - val_loss: 0.6881 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6880 - val_loss: 0.6883 - learning_rate: 5.0000e-05
# Last val loss 0.6880143284797668
# INFO: Dumping training history ...
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step
# RUNNING STEP 2
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.3573 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3581 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3578 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3576 - val_loss: 0.3575 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3570 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3573 - val_loss: 0.3575 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3569 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3580 - val_loss: 0.3573 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3575 - val_loss: 0.3575 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3578 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3581 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3581 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 13/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.3580 - val_loss: 0.3575 - learning_rate: 5.0000e-05
# Epoch 14/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3576 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 15/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3575 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 16/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3576 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 17/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3570 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Epoch 18/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.3570 - val_loss: 0.3574 - learning_rate: 5.0000e-05
# Last val loss 0.35738611221313477
# INFO: Dumping training history ...
# 1954/1954 ━━━━━━━━━━━━━━━━━━━━ 3s 855us/step
# ITERATION: 5
# RUNNING STEP 1
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.6869 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6898 - val_loss: 0.6853 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6909 - val_loss: 0.6852 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6872 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6886 - val_loss: 0.6853 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6905 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6867 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6864 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6897 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6898 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6860 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6878 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 13/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6848 - val_loss: 0.6853 - learning_rate: 5.0000e-05
# Epoch 14/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.6899 - val_loss: 0.6852 - learning_rate: 5.0000e-05
# Epoch 15/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6901 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 16/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6878 - val_loss: 0.6853 - learning_rate: 5.0000e-05
# Epoch 17/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6857 - val_loss: 0.6855 - learning_rate: 5.0000e-05
# Epoch 18/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6911 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 19/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.6905 - val_loss: 0.6852 - learning_rate: 5.0000e-05
# Last val loss 0.6851494312286377
# INFO: Dumping training history ...
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step
# RUNNING STEP 2
# ################################################################################
# Train events used: 1999872, Test events used: 399974
# ################################################################################
# Epoch 1/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.3550 - val_loss: 0.3543 - learning_rate: 5.0000e-05
# Epoch 2/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3547 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 3/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3543 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 4/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3536 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 5/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3543 - val_loss: 0.3543 - learning_rate: 5.0000e-05
# Epoch 6/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3541 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 7/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3548 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 8/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3543 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 9/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3544 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 10/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.3550 - val_loss: 0.3543 - learning_rate: 5.0000e-05
# Epoch 11/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3539 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 12/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3539 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 13/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.3548 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 14/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3539 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 15/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.3543 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 16/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3535 - val_loss: 0.3543 - learning_rate: 5.0000e-05
# Epoch 17/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.3544 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 18/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3546 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 19/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3540 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Epoch 20/100
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.3545 - val_loss: 0.3544 - learning_rate: 5.0000e-05
# Last val loss 0.3543497323989868
# INFO: Dumping training history ...
# 1954/1954 ━━━━━━━━━━━━━━━━━━━━ 2s 844us/step

# %% [markdown]
# ## Now, let's evaluate the model!

# %%
validation_data = np.random.normal(size=(5*nevts,ndim),loc=ndim*[1.0],scale=ndim*[1.0])
unfolded_weights  = omnifold.reweight(validation_data,omnifold.model2,batch_size=1000)
# Out:
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 4s 692us/step

# %%
print(unfolded_weights)
# Out:
# [0.08640765 0.96720618 0.03314349 ... 0.06623945 0.12280104 0.01072052]

# %% [markdown]
# ## More plots!

# %%
data_dict = {
    'Truth Distribution': gen_data[:,0],
    'Reconstructed Data': reco_data[:,0],
    'Generated MC': gen_mc[:,0],
    'Reconstructed MC': reco_mc[:,0],
    'Unfolded Data': validation_data[:,0],
}

weight_dict = {
    'Truth Distribution': data.weight,
    'Reconstructed Data': data.weight,
    'Generated MC': mc.weight,
    'Reconstructed MC': mc.weight,
    'Unfolded Data': unfolded_weights,
    }

fig,_ = HistRoutine(data_dict,'First Feature [a.u]',
                    reference_name = 'Truth Distribution',
                    weights = weight_dict,
                    plot_ratio = True,
                    binning = np.linspace(-3,5,20)
                    )
